# %% [markdown]
# # Data preparation - ethereum - v1

# %% [markdown]
# # Setup
#
# ## Library import
# We import all the required Python libraries

# %%
import os

# Data manipulation
from feature_engine.encoding import RareLabelEncoder, CountFrequencyEncoder
import pandas as pd
import numpy as np

# Visualizations
import plotly
import plotly.graph_objs as go
import plotly.offline as ply
plotly.offline.init_notebook_mode(connected=True)
import matplotlib as plt

import missingno as msno
from pycaret.classification import ClassificationExperiment
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from ydata_profiling import ProfileReport

# Autoreload extension
if 'autoreload' not in get_ipython().extension_manager.loaded:
    # %load_ext autoreload
    
# %autoreload 2

# Options for pandas
# pd.options.display.max_columns = None
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', 50)
pd.set_option('display.float_format', '{:.5f}'.format)
# pd.options.display.float_format = '{:.5f}'.format
# pd.options.display.max_rows = 120
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Local library import
# We import all the required local libraries libraries

# %%
os.chdir('../')
from src.utils.data_describe import breve_descricao, serie_nulos, cardinalidade, check_for_equal_columns
os.chdir('./notebooks/')

# %% [markdown]
# # Parameter definition
# We set all relevant parameters for our notebook. By convention, parameters are uppercase, while all the
# other variables follow Python's guidelines.

# %%
RAW_FOLDER = '../data/raw/'
INTERIM_FOLDER = '../data/interim/'
PROCESSED_FOLDER = '../data/processed/'
REPORTS_FOLDER = '../reports/'
RANDOM_STATE = 42

# %% [markdown]
# # Data import
# We retrieve all the required data for the analysis.

# %%
try:
    df_raw = pd.read_parquet(INTERIM_FOLDER + 'ethereum_complete.pqt')
    print(f'PARQUET file loaded. Shape: {df_raw.shape}')
except FileNotFoundError as e:
    df_raw = pd.read_csv(RAW_FOLDER + 'ethereum_complete.csv')
    df_raw.drop(columns=['Index'], inplace=True)
   
    df_raw.to_parquet(INTERIM_FOLDER +  'ethereum_complete.pqt', index=False)
    print(f'EXCEL file loaded and PARQUET created. Shape: {df_raw.shape}')
# Out:
# PARQUET file loaded. Shape: (4681, 49)

# %%
display(df_raw.head(3))
# Out:
#                                       Address  FLAG  Avg_min_between_sent_tnx  \
# 0  0x0020731604c882cf7bf8c444be97d17b19ea4316     1                1457.31000
# 1  0x002bf459dc58584d58886169ea0e80f3ca95ffaf     1                3976.50000
# 2  0x002f0c8119c16d310342d869ca8bf6ace34d9c39     1                 112.90000
#
#    Avg_min_between_received_tnx  Time_Diff_between_first_and_last_(Mins)  \
# 0                      34.12000                               4815.43000
# 1                     834.77000                               9622.53000
# 2                      31.87000                                321.42000
#
#    Sent_tnx  Received_Tnx  Number_of_Created_Contracts  \
# 0         3            13                            0
# 1         2             2                            0
# 2         2             3                            0
#
#    Unique_Received_From_Addresses  Unique_Sent_To_Addresses  \
# 0                              10                         3
# 1                               1                         2
# 2                               3                         1
#
#    min_value_received  max_value_received  avg_val_received  min_val_sent  \
# 0             1.00000             2.50105           1.34844       1.00087
# 1             0.58627             0.94751           0.76689       0.58541
# 2             0.00102             0.81780           0.43961       0.50039
#
#    max_val_sent  avg_val_sent  min_value_sent_to_contract  \
# 0      11.27787       5.84292                           0
# 1       0.94728       0.76635                           0
# 2       0.81751       0.65895                           0
#
#    max_val_sent_to_contract  avg_value_sent_to_contract  \
# 0                         0                           0
# 1                         0                           0
# 2                         0                           0
#
#    total_transactions_(including_tnx_to_create_contract)  total_Ether_sent  \
# 0                                                     16          17.52875
# 1                                                      4           1.53269
# 2                                                      5           1.31790
#
#    total_ether_received  total_ether_sent_contracts  total_ether_balance  \
# 0              17.52978                           0              0.00104
# 1               1.53378                           0              0.00109
# 2               1.31882                           0              0.00092
#
#    Total_ERC20_tnxs  ERC20_total_Ether_received  ERC20_total_ether_sent  \
# 0               NaN                         NaN                     NaN
# 1           1.00000                     1.33700                 0.00000
# 2           1.00000                     1.33700                 0.00000
#
#    ERC20_total_Ether_sent_contract  ERC20_uniq_sent_addr  ERC20_uniq_rec_addr  \
# 0                              NaN                   NaN                  NaN
# 1                          0.00000               0.00000              1.00000
# 2                          0.00000               0.00000              1.00000
#
#    ERC20_uniq_sent_addr.1  ERC20_uniq_rec_contract_addr  \
# 0                     NaN                           NaN
# 1                 0.00000                       1.00000
# 2                 0.00000                       1.00000
#
#    ERC20_avg_time_between_sent_tnx  ERC20_avg_time_between_rec_tnx  \
# 0                              NaN                             NaN
# 1                          0.00000                         0.00000
# 2                          0.00000                         0.00000
#
#    ERC20_avg_time_between_rec_2_tnx  ERC20_avg_time_between_contract_tnx  \
# 0                               NaN                                  NaN
# 1                           0.00000                              0.00000
# 2                           0.00000                              0.00000
#
#    ERC20_min_val_rec  ERC20_max_val_rec  ERC20_avg_val_rec  \
# 0                NaN                NaN                NaN
# 1            1.33700            1.33700            1.33700
# 2            1.33700            1.33700            1.33700
#
#    ERC20_min_val_sent  ERC20_max_val_sent  ERC20_avg_val_sent  \
# 0                 NaN                 NaN                 NaN
# 1             0.00000             0.00000             0.00000
# 2             0.00000             0.00000             0.00000
#
#    ERC20_min_val_sent_contract  ERC20_max_val_sent_contract  \
# 0                          NaN                          NaN
# 1                      0.00000                      0.00000
# 2                      0.00000                      0.00000
#
#    ERC20_avg_val_sent_contract  ERC20_uniq_sent_token_name  \
# 0                          NaN                         NaN
# 1                      0.00000                     0.00000
# 2                      0.00000                     0.00000
#
#    ERC20_uniq_rec_token_name ERC20_most_sent_token_type  \
# 0                        NaN                       None
# 1                    1.00000
# 2                    1.00000
#
#   ERC20_most_rec_token_type
# 0                      None
# 1     Blockwell say NOTSAFU
# 2     Blockwell say NOTSAFU

# %% [markdown]
# # Data cleaning
#
# 1. Remove duplicated registries
# 2. Remove duplicated columns
# 3. Remove constant columns
# 4. Remove equal columns
# 5. Transforming categorical features

# %% [markdown]
# ## Removing duplicated registries

# %%
df_cleaned = df_raw.copy()

# %%
df_cleaned.drop_duplicates(inplace=True)

print(f'Shape before data cleasing: {df_raw.shape}')
print(f'After dropping duplicated rows: {df_cleaned.shape}')
# Out:
# Shape before data cleasing: (4681, 49)
# After dropping duplicated rows: (4677, 49)

# %% [markdown]
# ## Removing duplicated columns

# %%
lst_duplicated_columns = [
    'ERC20_uniq_sent_addr.1', 'ERC20_avg_time_between_rec_2_tnx', 'ERC20_avg_val_sent_contract',
    'ERC20_max_val_sent_contract', 'ERC20_min_val_sent_contract',
]

df_cleaned.drop(columns=lst_duplicated_columns, inplace=True)

print(f'Shape before data cleasing: {df_raw.shape}')
print(f'After dropping duplicated columns: {df_cleaned.shape}')
# Out:
# Shape before data cleasing: (4681, 49)
# After dropping duplicated columns: (4677, 44)

# %% [markdown]
# ## Removing constant columns

# %%
lst_unitary_columns = [
    'total_ether_sent_contracts', 'min_value_sent_to_contract',
    'max_val_sent_to_contract', 'avg_value_sent_to_contract'
]

df_cleaned.drop(columns=lst_unitary_columns, inplace=True)

print(f'Shape before data cleasing: {df_raw.shape}')
print(f'After dropping duplicated columns: {df_cleaned.shape}')
# Out:
# Shape before data cleasing: (4681, 49)
# After dropping duplicated columns: (4677, 40)

# %% [markdown]
# ## Removing equal columns

# %%
lst_equal_columns = [
    'min_value_sent_to_contract', 'max_val_sent_to_contract', 'avg_value_sent_to_contract',
    'ERC20_avg_time_between_sent_tnx', 'ERC20_avg_time_between_rec_tnx'
]

for column in lst_equal_columns:
    try:
        df_cleaned.drop(columns=column, inplace=True)
    except:
        print(f"'{column}' was exluded before.")

print(30*'-')
print(f'Shape before data cleasing: {df_raw.shape}')
print(f'After dropping duplicated columns: {df_cleaned.shape}')
# Out:
# 'min_value_sent_to_contract' was exluded before.
# 'max_val_sent_to_contract' was exluded before.
# 'avg_value_sent_to_contract' was exluded before.
# ------------------------------
# Shape before data cleasing: (4681, 49)
# After dropping duplicated columns: (4677, 38)

# %% [markdown]
# ## Pre-processing categorical features

# %% [markdown]
# ### Replacing "    " and "0" to "no information"

# %%
for column in ['ERC20_most_sent_token_type', 'ERC20_most_rec_token_type']:
    df_cleaned.loc[df_cleaned[column].isnull(), column] = "0"
    for category in [" ", "", "0"]:
        df_cleaned[column] = df_cleaned[column].str.strip()
        df_cleaned[column].replace(category, "no information", inplace=True)
    

    display(
        pd.DataFrame(
            100*df_cleaned.loc[:, column].value_counts()/df_cleaned.loc[:, column].value_counts().sum()
        ).head(10)
    )
# Out:
#                                ERC20_most_sent_token_type
# no information                                   89.11696
# blockwell.ai KYC Casper Token                     1.38978
# OmiseGO                                           0.98354
# EOS                                               0.85525
# Golem                                             0.57729
# StatusNetwork                                     0.47039
# Tronix                                            0.32072
# Qtum                                              0.25657
# TenXPay                                           0.23519
# BAT                                               0.23519
#                                ERC20_most_rec_token_type
# no information                                  51.40047
# Blockwell say NOTSAFU                           16.65598
# OmiseGO                                          7.59034
# VIU                                              1.73188
# GSENetwork                                       1.71050
# INS Promo                                        1.15459
# Livepeer Token                                   1.13321
# blockwell.ai KYC Casper Token                    1.00492
# AICRYPTO                                         0.96216
# EOS                                              0.79111

# %% [markdown]
# # Experiment 01 - Only numerical features

# %%
df_cleaned_exp_01 = df_cleaned.drop(columns=['ERC20_most_sent_token_type', 'ERC20_most_rec_token_type']).copy()

# %% [markdown]
# ## Splitting data set

# %%
test_size = 0.15
train_size = 1 - test_size

lst_test_sample = df_cleaned_exp_01.sample(int(test_size*len(df_cleaned_exp_01)), random_state=RANDOM_STATE).index.values
lst_train_sample = df_cleaned_exp_01.drop(index=lst_test_sample).index.values

print(f"""
test_size: {test_size}
test_sample (registries): {len(lst_test_sample)}

train_size: {train_size}
train_sample (registries): {len(lst_train_sample)}
""")

df_cleaned_exp_01.loc[lst_train_sample, :].head()
# Out:
# test_size: 0.15
# test_sample (registries): 701
#
# train_size: 0.85
# train_sample (registries): 3976
#                                       Address  FLAG  Avg_min_between_sent_tnx  \
# 0  0x0020731604c882cf7bf8c444be97d17b19ea4316     1                1457.31000
# 1  0x002bf459dc58584d58886169ea0e80f3ca95ffaf     1                3976.50000
# 2  0x002f0c8119c16d310342d869ca8bf6ace34d9c39     1                 112.90000
# 3  0x0059b14e35dab1b4eee1e2926c7a5660da66f747     1                2300.37000
# 4  0x005b9f4516f8e640bbe48136901738b323c53b00     1                   0.00000
#
#    Avg_min_between_received_tnx  Time_Diff_between_first_and_last_(Mins)  \
# 0                      34.12000                               4815.43000
# 1                     834.77000                               9622.53000
# 2                      31.87000                                321.42000
# 3                      65.10000                              73091.00000
# 4                       0.00000                                  0.00000
#
#    Sent_tnx  Received_Tnx  Number_of_Created_Contracts  \
# 0         3            13                            0
# 1         2             2                            0
# 2         2             3                            0
# 3        29            98                            0
# 4         0             0                            0
#
#    Unique_Received_From_Addresses  Unique_Sent_To_Addresses  \
# 0                              10                         3
# 1                               1                         2
# 2                               3                         1
# 3                              89                        26
# 4                               0                         0
#
#    min_value_received  max_value_received  avg_val_received  min_val_sent  \
# 0             1.00000             2.50105           1.34844       1.00087
# 1             0.58627             0.94751           0.76689       0.58541
# 2             0.00102             0.81780           0.43961       0.50039
# 3             0.00078            15.72907           0.38322       0.00000
# 4             0.00000             0.00000           0.00000       0.00000
#
#    max_val_sent  avg_val_sent  \
# 0      11.27787       5.84292
# 1       0.94728       0.76635
# 2       0.81751       0.65895
# 3      36.70000       1.31496
# 4       0.00000       0.00000
#
#    total_transactions_(including_tnx_to_create_contract)  total_Ether_sent  \
# 0                                                     16          17.52875
# 1                                                      4           1.53269
# 2                                                      5           1.31790
# 3                                                    127          38.13377
# 4                                                      0           0.00000
#
#    total_ether_received  total_ether_balance  Total_ERC20_tnxs  \
# 0              17.52978              0.00104               NaN
# 1               1.53378              0.00109           1.00000
# 2               1.31882              0.00092           1.00000
# 3              37.55605             -0.57772          96.00000
# 4               0.00000              0.00000               NaN
#
#    ERC20_total_Ether_received  ERC20_total_ether_sent  \
# 0                         NaN                     NaN
# 1                     1.33700                 0.00000
# 2                     1.33700                 0.00000
# 3                142677.38290            120354.76840
# 4                         NaN                     NaN
#
#    ERC20_total_Ether_sent_contract  ERC20_uniq_sent_addr  ERC20_uniq_rec_addr  \
# 0                              NaN                   NaN                  NaN
# 1                          0.00000               0.00000              1.00000
# 2                          0.00000               0.00000              1.00000
# 3                          0.00000               6.00000             55.00000
# 4                              NaN                   NaN                  NaN
#
#    ERC20_uniq_rec_contract_addr  ERC20_avg_time_between_contract_tnx  \
# 0                           NaN                                  NaN
# 1                       1.00000                              0.00000
# 2                       1.00000                              0.00000
# 3                      37.00000                              0.00000
# 4                           NaN                                  NaN
#
#    ERC20_min_val_rec  ERC20_max_val_rec  ERC20_avg_val_rec  \
# 0                NaN                NaN                NaN
# 1            1.33700            1.33700            1.33700
# 2            1.33700            1.33700            1.33700
# 3            0.00000        26436.08100         1954.48470
# 4                NaN                NaN                NaN
#
#    ERC20_min_val_sent  ERC20_max_val_sent  ERC20_avg_val_sent  \
# 0                 NaN                 NaN                 NaN
# 1             0.00000             0.00000             0.00000
# 2             0.00000             0.00000             0.00000
# 3             0.00000         81324.07460          5232.81602
# 4                 NaN                 NaN                 NaN
#
#    ERC20_uniq_sent_token_name  ERC20_uniq_rec_token_name
# 0                         NaN                        NaN
# 1                     0.00000                    1.00000
# 2                     0.00000                    1.00000
# 3                    22.00000                   37.00000
# 4                         NaN                        NaN

# %% [markdown]
# ## Exporting

# %%
df_cleaned_exp_01.loc[lst_train_sample, :].to_parquet(INTERIM_FOLDER + 'df_train_exp_01.pqt')
df_cleaned_exp_01.loc[lst_test_sample, :].to_parquet(INTERIM_FOLDER + 'df_test_exp_01.pqt')

# %% [markdown]
# # Experiment 02 - Categorical features encoded by frequency

# %%
df_cleaned_exp_02 = df_cleaned.copy()

# %% [markdown]
# ## Splitting data set

# %%
test_size = 0.15
train_size = 1 - test_size

lst_test_sample = df_cleaned_exp_02.sample(int(test_size*len(df_cleaned_exp_02)), random_state=RANDOM_STATE).index.values
lst_train_sample = df_cleaned_exp_02.drop(index=lst_test_sample).index.values

df_cleaned_train_exp_02 = df_cleaned_exp_02.loc[lst_train_sample, :].copy()
df_cleaned_test_exp_02 = df_cleaned_exp_02.loc[lst_test_sample, :].copy()

print(f"""
test_size: {test_size}
test_sample (registries): {len(lst_test_sample)}

train_size: {train_size}
train_sample (registries): {len(lst_train_sample)}
""")

df_cleaned_train_exp_02.loc[lst_train_sample, :].head()
# Out:
# test_size: 0.15
# test_sample (registries): 701
#
# train_size: 0.85
# train_sample (registries): 3976
#                                       Address  FLAG  Avg_min_between_sent_tnx  \
# 0  0x0020731604c882cf7bf8c444be97d17b19ea4316     1                1457.31000
# 1  0x002bf459dc58584d58886169ea0e80f3ca95ffaf     1                3976.50000
# 2  0x002f0c8119c16d310342d869ca8bf6ace34d9c39     1                 112.90000
# 3  0x0059b14e35dab1b4eee1e2926c7a5660da66f747     1                2300.37000
# 4  0x005b9f4516f8e640bbe48136901738b323c53b00     1                   0.00000
#
#    Avg_min_between_received_tnx  Time_Diff_between_first_and_last_(Mins)  \
# 0                      34.12000                               4815.43000
# 1                     834.77000                               9622.53000
# 2                      31.87000                                321.42000
# 3                      65.10000                              73091.00000
# 4                       0.00000                                  0.00000
#
#    Sent_tnx  Received_Tnx  Number_of_Created_Contracts  \
# 0         3            13                            0
# 1         2             2                            0
# 2         2             3                            0
# 3        29            98                            0
# 4         0             0                            0
#
#    Unique_Received_From_Addresses  Unique_Sent_To_Addresses  \
# 0                              10                         3
# 1                               1                         2
# 2                               3                         1
# 3                              89                        26
# 4                               0                         0
#
#    min_value_received  max_value_received  avg_val_received  min_val_sent  \
# 0             1.00000             2.50105           1.34844       1.00087
# 1             0.58627             0.94751           0.76689       0.58541
# 2             0.00102             0.81780           0.43961       0.50039
# 3             0.00078            15.72907           0.38322       0.00000
# 4             0.00000             0.00000           0.00000       0.00000
#
#    max_val_sent  avg_val_sent  \
# 0      11.27787       5.84292
# 1       0.94728       0.76635
# 2       0.81751       0.65895
# 3      36.70000       1.31496
# 4       0.00000       0.00000
#
#    total_transactions_(including_tnx_to_create_contract)  total_Ether_sent  \
# 0                                                     16          17.52875
# 1                                                      4           1.53269
# 2                                                      5           1.31790
# 3                                                    127          38.13377
# 4                                                      0           0.00000
#
#    total_ether_received  total_ether_balance  Total_ERC20_tnxs  \
# 0              17.52978              0.00104               NaN
# 1               1.53378              0.00109           1.00000
# 2               1.31882              0.00092           1.00000
# 3              37.55605             -0.57772          96.00000
# 4               0.00000              0.00000               NaN
#
#    ERC20_total_Ether_received  ERC20_total_ether_sent  \
# 0                         NaN                     NaN
# 1                     1.33700                 0.00000
# 2                     1.33700                 0.00000
# 3                142677.38290            120354.76840
# 4                         NaN                     NaN
#
#    ERC20_total_Ether_sent_contract  ERC20_uniq_sent_addr  ERC20_uniq_rec_addr  \
# 0                              NaN                   NaN                  NaN
# 1                          0.00000               0.00000              1.00000
# 2                          0.00000               0.00000              1.00000
# 3                          0.00000               6.00000             55.00000
# 4                              NaN                   NaN                  NaN
#
#    ERC20_uniq_rec_contract_addr  ERC20_avg_time_between_contract_tnx  \
# 0                           NaN                                  NaN
# 1                       1.00000                              0.00000
# 2                       1.00000                              0.00000
# 3                      37.00000                              0.00000
# 4                           NaN                                  NaN
#
#    ERC20_min_val_rec  ERC20_max_val_rec  ERC20_avg_val_rec  \
# 0                NaN                NaN                NaN
# 1            1.33700            1.33700            1.33700
# 2            1.33700            1.33700            1.33700
# 3            0.00000        26436.08100         1954.48470
# 4                NaN                NaN                NaN
#
#    ERC20_min_val_sent  ERC20_max_val_sent  ERC20_avg_val_sent  \
# 0                 NaN                 NaN                 NaN
# 1             0.00000             0.00000             0.00000
# 2             0.00000             0.00000             0.00000
# 3             0.00000         81324.07460          5232.81602
# 4                 NaN                 NaN                 NaN
#
#    ERC20_uniq_sent_token_name  ERC20_uniq_rec_token_name  \
# 0                         NaN                        NaN
# 1                     0.00000                    1.00000
# 2                     0.00000                    1.00000
# 3                    22.00000                   37.00000
# 4                         NaN                        NaN
#
#   ERC20_most_sent_token_type ERC20_most_rec_token_type
# 0             no information            no information
# 1             no information     Blockwell say NOTSAFU
# 2             no information     Blockwell say NOTSAFU
# 3                      OCoin                     OCoin
# 4             no information            no information

# %% [markdown]
# ## Preprocessing

# %%
df_cleaned_train_exp_02 = df_cleaned_exp_02.loc[lst_train_sample, :].copy()
df_cleaned_test_exp_02 = df_cleaned_exp_02.loc[lst_test_sample, :].copy()

pipe = Pipeline([
    ('rare', RareLabelEncoder(
        n_categories=2, max_n_categories=3, replace_with='rare', tol=0.10,
        variables=['ERC20_most_sent_token_type', 'ERC20_most_rec_token_type']
    )),
    ('frq', CountFrequencyEncoder(
        encoding_method='frequency',
        variables=['ERC20_most_sent_token_type', 'ERC20_most_rec_token_type']
    ))
])

df_cleaned_train_exp_02 = pipe.fit_transform(df_cleaned_train_exp_02)
df_cleaned_test_exp_02 = pipe.transform(df_cleaned_test_exp_02)

display(df_cleaned_train_exp_02['ERC20_most_rec_token_type'].value_counts())
display(df_cleaned_train_exp_02['ERC20_most_sent_token_type'].value_counts())
# Out:
# 0.51434    2045
# 0.31866    1267
# 0.16700     664
# Name: ERC20_most_rec_token_type, dtype: int64
# 0.89009    3539
# 0.10991     437
# Name: ERC20_most_sent_token_type, dtype: int64

# %%
df_cleaned_test_exp_02
# Out:
#                                          Address  FLAG  \
# 2493  0x3f023af0a857d0a1591d887194e045301ea2d585     0
# 33    0x046e3a705d9bcd0e53d2b45161b48e39f4bc4090     1
# 3683  0x350d038b70e4acea961427347c6bed44ad8a3d50     0
# 4133  0x94bbd18febb681d0300f19e92832b15bfef81c09     0
# 3193  0xd0b61258d4b31d4718765a133356b7eaa720cfc8     0
# ...                                          ...   ...
# 2183  0x00472c1e4275230354dbe5007a5976053f12610a     0
# 2873  0x8c73844ec547b74d12ed3aa136365c93d0a16b87     0
# 80    0x096c13f383a32253e238bc148307753d14868235     1
# 1467  0xaa2498d85ba7559006f90110a4bc33c10a06c1af     1
# 2726  0x6f4ef148de522bdb3198f3858b5c69d3e4541777     0
#
#       Avg_min_between_sent_tnx  Avg_min_between_received_tnx  \
# 2493               17491.39000                   30810.71000
# 33                   140.50000                       0.00000
# 3683                   0.00000                    2031.71000
# 4133                7133.41000                   31214.68000
# 3193                   0.00000                       0.00000
# ...                        ...                           ...
# 2183                   2.12000                       0.92000
# 2873                 163.78000                       0.82000
# 80                     0.00000                       0.00000
# 1467                1989.69000                     135.30000
# 2726                  10.35000                   59074.60000
#
#       Time_Diff_between_first_and_last_(Mins)  Sent_tnx  Received_Tnx  \
# 2493                             259001.92000         6             5
# 33                                  281.00000         2             1
# 3683                             201139.00000         0            99
# 4133                             378118.77000        18             8
# 3193                                  1.08000         1             1
# ...                                       ...       ...           ...
# 2183                              21206.93000      9996             4
# 2873                                329.18000         2             2
# 80                                 1252.55000         1             1
# 1467                              26876.90000         8            81
# 2726                             354509.72000         6             6
#
#       Number_of_Created_Contracts  Unique_Received_From_Addresses  \
# 2493                            0                               5
# 33                              0                               1
# 3683                            1                               7
# 4133                            0                               7
# 3193                            0                               1
# ...                           ...                             ...
# 2183                            3                               3
# 2873                            0                               2
# 80                              0                               1
# 1467                            0                              62
# 2726                            0                               1
#
#       Unique_Sent_To_Addresses  min_value_received  max_value_received  \
# 2493                         2             0.70950           199.99958
# 33                           2             5.00000             5.00000
# 3683                         0             0.00000             8.99900
# 4133                        11             0.00100           187.06000
# 3193                         1             0.11170             0.11170
# ...                        ...                 ...                 ...
# 2183                         2             1.00000            20.00000
# 2873                         2             1.84412            99.15588
# 80                           1             0.22482             0.22482
# 1467                         8             0.00000             2.00000
# 2726                         6             2.98479           266.73638
#
#       avg_val_received  min_val_sent  max_val_sent  avg_val_sent  \
# 2493          45.16721       0.00371     199.99516      37.63876
# 33             5.00000       2.49694       2.50000       2.49847
# 3683           0.95540       0.00000       0.00000       0.00000
# 4133          33.82849       0.00000     187.25300      15.04739
# 3193           0.11170       0.11078       0.11078       0.11078
# ...                ...           ...           ...           ...
# 2183          11.00000       0.00000       0.00000       0.00000
# 2873          50.50000       0.80000     100.19897      50.49949
# 80             0.22482       0.22478       0.22478       0.22478
# 1467           0.63118       2.40315       7.11610       6.49010
# 2726          48.27772       2.98437     266.73596      48.27728
#
#       total_transactions_(including_tnx_to_create_contract)  total_Ether_sent  \
# 2493                                                     11         225.83257
# 33                                                        3           4.99694
# 3683                                                    100           0.00000
# 4133                                                     26         270.85300
# 3193                                                      2           0.11078
# ...                                                     ...               ...
# 2183                                                  10003           0.00000
# 2873                                                      4         100.99897
# 80                                                        2           0.22478
# 1467                                                     89          51.92081
# 2726                                                     12         289.66371
#
#       total_ether_received  total_ether_balance  Total_ERC20_tnxs  \
# 2493             225.83608              0.00351           0.00000
# 33                 5.00000              0.00306           1.00000
# 3683              94.58509             94.58509           2.00000
# 4133             270.62790             -0.22510          22.00000
# 3193               0.11169              0.00091           0.00000
# ...                    ...                  ...               ...
# 2183              44.00000             44.00000          34.00000
# 2873             101.00000              0.00103           0.00000
# 80                 0.22482              0.00004           1.00000
# 1467              51.12590             -0.79491               NaN
# 2726             289.66631              0.00260           0.00000
#
#       ERC20_total_Ether_received  ERC20_total_ether_sent  \
# 2493                     0.00000                 0.00000
# 33                      13.37000                 0.00000
# 3683                     2.06025                 0.00000
# 4133               1141890.12100           1141889.49000
# 3193                     0.00000                 0.00000
# ...                          ...                     ...
# 2183            3106124503.00000               100.00000
# 2873                     0.00000                 0.00000
# 80                      13.37000                 0.00000
# 1467                         NaN                     NaN
# 2726                     0.00000                 0.00000
#
#       ERC20_total_Ether_sent_contract  ERC20_uniq_sent_addr  \
# 2493                          0.00000               0.00000
# 33                            0.00000               0.00000
# 3683                          0.00000               0.00000
# 4133                          0.00000               7.00000
# 3193                          0.00000               0.00000
# ...                               ...                   ...
# 2183                          0.00000               1.00000
# 2873                          0.00000               0.00000
# 80                            0.00000               0.00000
# 1467                              NaN                   NaN
# 2726                          0.00000               0.00000
#
#       ERC20_uniq_rec_addr  ERC20_uniq_rec_contract_addr  \
# 2493              0.00000                       0.00000
# 33                1.00000                       1.00000
# 3683              2.00000                       2.00000
# 4133              7.00000                       6.00000
# 3193              0.00000                       0.00000
# ...                   ...                           ...
# 2183             24.00000                      30.00000
# 2873              0.00000                       0.00000
# 80                1.00000                       1.00000
# 1467                  NaN                           NaN
# 2726              0.00000                       0.00000
#
#       ERC20_avg_time_between_contract_tnx  ERC20_min_val_rec  \
# 2493                              0.00000            0.00000
# 33                                0.00000           13.37000
# 3683                              0.00000            0.74222
# 4133                              0.00000            0.00000
# 3193                              0.00000            0.00000
# ...                                   ...                ...
# 2183                              0.00000            0.00000
# 2873                              0.00000            0.00000
# 80                                0.00000           13.37000
# 1467                                  NaN                NaN
# 2726                              0.00000            0.00000
#
#       ERC20_max_val_rec  ERC20_avg_val_rec  ERC20_min_val_sent  \
# 2493            0.00000            0.00000             0.00000
# 33             13.37000           13.37000             0.00000
# 3683            1.31803            1.03012             0.00000
# 4133       342426.60000        95157.51010             0.00000
# 3193            0.00000            0.00000             0.00000
# ...                 ...                ...                 ...
# 2183   1553054037.00000     94124984.93000           100.00000
# 2873            0.00000            0.00000             0.00000
# 80             13.37000           13.37000             0.00000
# 1467                NaN                NaN                 NaN
# 2726            0.00000            0.00000             0.00000
#
#       ERC20_max_val_sent  ERC20_avg_val_sent  ERC20_uniq_sent_token_name  \
# 2493             0.00000             0.00000                     0.00000
# 33               0.00000             0.00000                     0.00000
# 3683             0.00000             0.00000                     0.00000
# 4133        342426.00000        114188.94900                     5.00000
# 3193             0.00000             0.00000                     0.00000
# ...                  ...                 ...                         ...
# 2183           100.00000           100.00000                     1.00000
# 2873             0.00000             0.00000                     0.00000
# 80               0.00000             0.00000                     0.00000
# 1467                 NaN                 NaN                         NaN
# 2726             0.00000             0.00000                     0.00000
#
#       ERC20_uniq_rec_token_name  ERC20_most_sent_token_type  \
# 2493                    0.00000                     0.89009
# 33                      1.00000                     0.89009
# 3683                    2.00000                     0.89009
# 4133                    6.00000                     0.10991
# 3193                    0.00000                     0.89009
# ...                         ...                         ...
# 2183                   28.00000                     0.10991
# 2873                    0.00000                     0.89009
# 80                      1.00000                     0.89009
# 1467                        NaN                     0.89009
# 2726                    0.00000                     0.89009
#
#       ERC20_most_rec_token_type
# 2493                    0.51434
# 33                      0.16700
# 3683                    0.31866
# 4133                    0.31866
# 3193                    0.51434
# ...                         ...
# 2183                    0.31866
# 2873                    0.51434
# 80                      0.16700
# 1467                    0.51434
# 2726                    0.51434
#
# [701 rows x 38 columns]

# %% [markdown]
# ## Exporting

# %%
df_cleaned_train_exp_02.to_parquet(INTERIM_FOLDER + 'df_train_exp_02.pqt')
df_cleaned_test_exp_02.to_parquet(INTERIM_FOLDER + 'df_test_exp_02.pqt')
